# %% [markdown]
# <a href="https://colab.research.google.com/github/vsw-812/DWM/blob/main/Experiment3.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
#Experiment 3
import pandas as pd
from mlxtend.frequent_patterns import apriori
#from apyori import apriori
from mlxtend.frequent_patterns import association_rules

# %%
df=pd.read_csv('OnlineRetail.csv',encoding = 'unicode_escape')
df.head()
# Out:
#   InvoiceNo StockCode  ... CustomerID         Country
# 0    536365    85123A  ...    17850.0  United Kingdom
# 1    536365     71053  ...    17850.0  United Kingdom
# 2    536365    84406B  ...    17850.0  United Kingdom
# 3    536365    84029G  ...    17850.0  United Kingdom
# 4    536365    84029E  ...    17850.0  United Kingdom
#
# [5 rows x 8 columns]

# %%
#data cleaning

df['Description']=df['Description'].str.strip()
df.dropna(axis=0,subset=['InvoiceNo'],inplace=True)
df=df[~df['InvoiceNo'].str.contains('C')]
df.head()
# Out:
#   InvoiceNo StockCode  ... CustomerID         Country
# 0    536365    85123A  ...    17850.0  United Kingdom
# 1    536365     71053  ...    17850.0  United Kingdom
# 2    536365    84406B  ...    17850.0  United Kingdom
# 3    536365    84029G  ...    17850.0  United Kingdom
# 4    536365    84029E  ...    17850.0  United Kingdom
#
# [5 rows x 8 columns]

# %%
df.Country.unique()
# Out:
# array(['United Kingdom', 'France', 'Australia', 'Netherlands', 'Germany',
#        'Norway', 'EIRE', 'Switzerland', 'Spain', 'Poland', 'Portugal',
#        'Italy', 'Belgium', 'Lithuania', 'Japan', 'Iceland',
#        'Channel Islands', 'Denmark', 'Cyprus', 'Sweden', 'Finland',
#        'Austria', 'Bahrain', 'Israel', 'Greece', 'Hong Kong', 'Singapore',
#        'Lebanon', 'United Arab Emirates', nan], dtype=object)

# %%
#Consolidation of item in transaction per row with each products
#minimising dataset 

basket=(df[df['Country']=='Germany'].groupby(['InvoiceNo','Description'])['Quantity'].sum().unstack().reset_index().fillna(0).set_index('InvoiceNo'))
basket
# Out:
# Description  10 COLOUR SPACEBOY PEN  ...  ZINC WILLIE WINKIE  CANDLE STICK
# InvoiceNo                            ...
# 536527                          0.0  ...                               0.0
# 536840                          0.0  ...                               0.0
# 536861                          0.0  ...                               0.0
# 536967                          0.0  ...                               0.0
# 536983                          0.0  ...                               0.0
# ...                             ...  ...                               ...
# 544281                          0.0  ...                               0.0
# 544302                          0.0  ...                               0.0
# 544340                          0.0  ...                               0.0
# 544483                          0.0  ...                               0.0
# 544573                          0.0  ...                               0.0
#
# [77 rows x 682 columns]

# %%
#Lots of zero value
#Converting negative values to zero and positive values to one

def conversion(x):
  if x<=0:
    return 0
  if x>=1:
    return 1

basket_sets=basket.applymap(conversion)
basket_sets.drop('POSTAGE',inplace=True,axis=1)
basket_sets
# Out:
# Description  10 COLOUR SPACEBOY PEN  ...  ZINC WILLIE WINKIE  CANDLE STICK
# InvoiceNo                            ...
# 536527                            0  ...                                 0
# 536840                            0  ...                                 0
# 536861                            0  ...                                 0
# 536967                            0  ...                                 0
# 536983                            0  ...                                 0
# ...                             ...  ...                               ...
# 544281                            0  ...                                 0
# 544302                            0  ...                                 0
# 544340                            0  ...                                 0
# 544483                            0  ...                                 0
# 544573                            0  ...                                 0
#
# [77 rows x 681 columns]

# %%
frequent_itemsets = apriori(basket_sets, min_support=0.07, use_colnames=True)

# %%
rules = association_rules(frequent_itemsets, metric="lift", min_threshold=1)
rules.head()
# Out:
#                   antecedents                 consequents  ...  leverage  conviction
# 0    (6 RIBBONS RUSTIC CHARM)  (REGENCY CAKESTAND 3 TIER)  ...  0.055153    2.415584
# 1  (REGENCY CAKESTAND 3 TIER)    (6 RIBBONS RUSTIC CHARM)  ...  0.055153    1.471861
# 2    (JAM JAR WITH GREEN LID)     (JAM JAR WITH PINK LID)  ...  0.069826         inf
# 3     (JAM JAR WITH PINK LID)    (JAM JAR WITH GREEN LID)  ...  0.069826    3.688312
# 4    (JAM JAR WITH GREEN LID)    (JAM MAKING SET PRINTED)  ...  0.065778         inf
#
# [5 rows x 9 columns]

# %%
rules[ (rules['lift'] >= 6) &
      (rules['confidence'] >= 0.8) ]
# Out:
#                                          antecedents  ... conviction
# 2                           (JAM JAR WITH GREEN LID)  ...        inf
# 4                           (JAM JAR WITH GREEN LID)  ...        inf
# 12                  (STRAWBERRY CERAMIC TRINKET BOX)  ...   6.454545
# 13                  (SWEETHEART CERAMIC TRINKET BOX)  ...        inf
# 14  (JAM JAR WITH GREEN LID, JAM MAKING SET PRINTED)  ...        inf
# 15   (JAM JAR WITH GREEN LID, JAM JAR WITH PINK LID)  ...        inf
# 16   (JAM JAR WITH PINK LID, JAM MAKING SET PRINTED)  ...   6.454545
# 17                          (JAM JAR WITH GREEN LID)  ...        inf
#
# [8 rows x 9 columns]
